# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
events=pd.read_csv(r"C:\Users\Gopal\Downloads\athlete_events.csv\athlete_events.csv")
noc=pd.read_csv(r"C:\Users\Gopal\Downloads\noc_regions.csv")

# %%
events.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %%
noc.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
df=events.merge(noc, on='NOC', how='left')

# %%
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal       region notes
# 0       Basketball Men's Basketball   NaN        China   NaN
# 1      Judo Men's Extra-Lightweight   NaN        China   NaN
# 2           Football Men's Football   NaN      Denmark   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold      Denmark   NaN
# 4  Speed Skating Women's 500 metres   NaN  Netherlands   NaN

# %%
print('The shape of the dataset : ', df.shape)
# Out:
# The shape of the dataset :  (271116, 17)

# %% [markdown]
# ### Columns name

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal', 'region', 'notes'],
#       dtype='object')

# %% [markdown]
# ### Data types present in the columns

# %%
df.dtypes
# Out:
# ID          int64
# Name       object
# Sex        object
# Age       float64
# Height    float64
# Weight    float64
# Team       object
# NOC        object
# Games      object
# Year        int64
# Season     object
# City       object
# Sport      object
# Event      object
# Medal      object
# region     object
# notes      object
# dtype: object

# %% [markdown]
# ### Summary of dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 271116 entries, 0 to 271115
# Data columns (total 17 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
#  15  region  270746 non-null  object
#  16  notes   5039 non-null    object
# dtypes: float64(3), int64(2), object(12)
# memory usage: 37.2+ MB

# %%
df.nunique()
# Out:
# ID        135571
# Name      134732
# Sex            2
# Age           74
# Height        95
# Weight       220
# Team        1184
# NOC          230
# Games         51
# Year          35
# Season         2
# City          42
# Sport         66
# Event        765
# Medal          3
# region       205
# notes         21
# dtype: int64

# %% [markdown]
# ### Statistical properties of dataset

# %%
df.describe().T
# Out:
#            count          mean           std     min      25%      50%  \
# ID      271116.0  68248.954396  39022.286345     1.0  34643.0  68205.0
# Age     261642.0     25.556898      6.393561    10.0     21.0     24.0
# Height  210945.0    175.338970     10.518462   127.0    168.0    175.0
# Weight  208241.0     70.702393     14.348020    25.0     60.0     70.0
# Year    271116.0   1978.378480     29.877632  1896.0   1960.0   1988.0
#
#               75%       max
# ID      102097.25  135571.0
# Age         28.00      97.0
# Height     183.00     226.0
# Weight      79.00     214.0
# Year      2002.00    2016.0

# %%
df.describe(include=['object']).T
# Out:
#          count  unique                      top    freq
# Name    271116  134732     Robert Tait McKenzie      58
# Sex     271116       2                        M  196594
# Team    271116    1184            United States   17847
# NOC     271116     230                      USA   18853
# Games   271116      51              2000 Summer   13821
# Season  271116       2                   Summer  222552
# City    271116      42                   London   22426
# Sport   271116      66                Athletics   38624
# Event   271116     765  Football Men's Football    5733
# Medal    39783       3                     Gold   13372
# region  270746     205                      USA   18853
# notes     5039      21               Yugoslavia    2583

# %%
df.isnull().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# region       370
# notes     266077
# dtype: int64

# %%
events=df.groupby(['Year', 'Season', 'City'], as_index=False).first()

# %%
events.head()
# Out:
#    Year  Season       City    ID                         Name Sex   Age  \
# 0  1896  Summer     Athina  1724       Aristidis Akratopoulos   M  24.0
# 1  1900  Summer      Paris     4         Edgar Lindenau Aabye   M  34.0
# 2  1904  Summer  St. Louis   404  Louis Grenville "Lou" Abell   M  19.0
# 3  1906  Summer     Athina   139       George "Ioannis" Abbot   M  21.0
# 4  1908  Summer     London   635              Alfredo Accorsi   M  27.0
#
#    Height  Weight              Team  NOC        Games       Sport  \
# 0   183.0    66.0            Greece  GRE  1896 Summer      Tennis
# 1   168.0    60.0    Denmark/Sweden  DEN  1900 Summer  Tug-Of-War
# 2   168.0    77.0  Vesper Boat Club  USA  1904 Summer      Rowing
# 3   182.0    77.0     Thessalonki-1  GRE  1906 Summer    Football
# 4   188.0    78.0             Italy  ITA  1908 Summer  Gymnastics
#
#                               Event   Medal   region         notes
# 0              Tennis Men's Singles  Silver   Greece          None
# 1       Tug-Of-War Men's Tug-Of-War    Gold  Denmark       Bohemia
# 2         Rowing Men's Coxed Eights    Gold      USA  Newfoundland
# 3           Football Men's Football  Bronze   Greece         Crete
# 4  Gymnastics Men's Team All-Around  Bronze    Italy   Australasia

# %% [markdown]
# ## Summer Olympics

# %%
event_summer = events.loc[(events['Season']=='Summer'),['Year','Season','City']]

# %%
event_summer
# Out:
#     Year  Season            City
# 0   1896  Summer          Athina
# 1   1900  Summer           Paris
# 2   1904  Summer       St. Louis
# 3   1906  Summer          Athina
# 4   1908  Summer          London
# 5   1912  Summer       Stockholm
# 6   1920  Summer       Antwerpen
# 7   1924  Summer           Paris
# 9   1928  Summer       Amsterdam
# 11  1932  Summer     Los Angeles
# 13  1936  Summer          Berlin
# 15  1948  Summer          London
# 17  1952  Summer        Helsinki
# 19  1956  Summer       Melbourne
# 20  1956  Summer       Stockholm
# 22  1960  Summer            Roma
# 24  1964  Summer           Tokyo
# 26  1968  Summer     Mexico City
# 28  1972  Summer          Munich
# 30  1976  Summer        Montreal
# 32  1980  Summer          Moskva
# 34  1984  Summer     Los Angeles
# 36  1988  Summer           Seoul
# 38  1992  Summer       Barcelona
# 41  1996  Summer         Atlanta
# 43  2000  Summer          Sydney
# 45  2004  Summer          Athina
# 47  2008  Summer         Beijing
# 49  2012  Summer          London
# 51  2016  Summer  Rio de Janeiro

# %% [markdown]
# ## Winter Olympics

# %%
event_winter=events.loc[(events['Season']=='Winter'),['Year','Season','City']]

# %%
event_winter
# Out:
#     Year  Season                    City
# 8   1924  Winter                Chamonix
# 10  1928  Winter            Sankt Moritz
# 12  1932  Winter             Lake Placid
# 14  1936  Winter  Garmisch-Partenkirchen
# 16  1948  Winter            Sankt Moritz
# 18  1952  Winter                    Oslo
# 21  1956  Winter       Cortina d'Ampezzo
# 23  1960  Winter            Squaw Valley
# 25  1964  Winter               Innsbruck
# 27  1968  Winter                Grenoble
# 29  1972  Winter                 Sapporo
# 31  1976  Winter               Innsbruck
# 33  1980  Winter             Lake Placid
# 35  1984  Winter                Sarajevo
# 37  1988  Winter                 Calgary
# 39  1992  Winter             Albertville
# 40  1994  Winter             Lillehammer
# 42  1998  Winter                  Nagano
# 44  2002  Winter          Salt Lake City
# 46  2006  Winter                  Torino
# 48  2010  Winter               Vancouver
# 50  2014  Winter                   Sochi

# %% [markdown]
# ### Number of unique sports in olympic

# %%
print(df['Sport'].unique())
# Out:
# ['Basketball' 'Judo' 'Football' 'Tug-Of-War' 'Speed Skating'
#  'Cross Country Skiing' 'Athletics' 'Ice Hockey' 'Swimming' 'Badminton'
#  'Sailing' 'Biathlon' 'Gymnastics' 'Art Competitions' 'Alpine Skiing'
#  'Handball' 'Weightlifting' 'Wrestling' 'Luge' 'Water Polo' 'Hockey'
#  'Rowing' 'Bobsleigh' 'Fencing' 'Equestrianism' 'Shooting' 'Boxing'
#  'Taekwondo' 'Cycling' 'Diving' 'Canoeing' 'Tennis' 'Modern Pentathlon'
#  'Figure Skating' 'Golf' 'Softball' 'Archery' 'Volleyball'
#  'Synchronized Swimming' 'Table Tennis' 'Nordic Combined' 'Baseball'
#  'Rhythmic Gymnastics' 'Freestyle Skiing' 'Rugby Sevens' 'Trampolining'
#  'Beach Volleyball' 'Triathlon' 'Ski Jumping' 'Curling' 'Snowboarding'
#  'Rugby' 'Short Track Speed Skating' 'Skeleton' 'Lacrosse' 'Polo'
#  'Cricket' 'Racquets' 'Motorboating' 'Military Ski Patrol' 'Croquet'
#  'Jeu De Paume' 'Roque' 'Alpinism' 'Basque Pelota' 'Aeronautics']

# %%
print(df['Sport'].nunique())
# Out:
# 66

# %%
plt.scatter(df.Height, df.Weight)
plt.xlabel('Height')
plt.ylabel('Weight')
plt.show()

# %%
sns.scatterplot(x='Height', y='Weight', hue='Sex', data=df)
plt.show()

# %%
  #  using discrete color scheme
sns.scatterplot(x='Height', y='Weight', hue='Sex', data = df, palette='Set2')
plt.show()

# %%
## using this graph we can find out most of the people are of which age
sns.displot(df['Age'])
plt.show()

# %%
  ## Histogram
plt.hist(df.Age)
plt.ylabel("Frequency")
plt.xlabel("Age")
plt.show()

# %%
sns.countplot(x="Sex", data=df, palette = 'Set3')
plt.show()

# %% [markdown]
# ### Top Countries in Olympic Medals

# %%
topc = df.groupby('region')['Medal'].count().reset_index()
topc
# Out:
#                       region  Medal
# 0                Afghanistan      2
# 1                    Albania      0
# 2                    Algeria     17
# 3             American Samoa      0
# 4                    Andorra      0
# ..                       ...    ...
# 200  Virgin Islands, British      0
# 201       Virgin Islands, US      1
# 202                    Yemen      0
# 203                   Zambia      2
# 204                 Zimbabwe     22
#
# [205 rows x 2 columns]

# %%
topc = df.groupby('region')['Medal'].count().nlargest(20).reset_index()

# %%
topc.head(20)
# Out:
#             region  Medal
# 0              USA   5637
# 1           Russia   3947
# 2          Germany   3756
# 3               UK   2068
# 4           France   1777
# 5            Italy   1637
# 6           Sweden   1536
# 7           Canada   1352
# 8        Australia   1349
# 9          Hungary   1135
# 10     Netherlands   1040
# 11          Norway   1033
# 12           China    993
# 13           Japan    913
# 14         Finland    900
# 15     Switzerland    691
# 16         Romania    653
# 17  Czech Republic    644
# 18     South Korea    638
# 19         Denmark    597

# %%
plt.figure(figsize=(12, 10))
sns.barplot(x='region', y='Medal', data=topc)
plt.xlabel('regions')
plt.ylabel('Number of medals')
plt.title('Top Countries in Olympic Medals')
plt.xticks(rotation=45)
plt.show()

# %%
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal       region notes
# 0       Basketball Men's Basketball   NaN        China   NaN
# 1      Judo Men's Extra-Lightweight   NaN        China   NaN
# 2           Football Men's Football   NaN      Denmark   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold      Denmark   NaN
# 4  Speed Skating Women's 500 metres   NaN  Netherlands   NaN

# %% [markdown]
# ### Number of medals of countries in summer olympics

# %%
df[df['Season'] == 'Summer'].groupby(['region', 'Medal']).size().reset_index()
# Out:
#           region   Medal   0
# 0    Afghanistan  Bronze   2
# 1        Algeria  Bronze   8
# 2        Algeria    Gold   5
# 3        Algeria  Silver   4
# 4      Argentina  Bronze  91
# ..           ...     ...  ..
# 318       Zambia  Bronze   1
# 319       Zambia  Silver   1
# 320     Zimbabwe  Bronze   1
# 321     Zimbabwe    Gold  17
# 322     Zimbabwe  Silver   4
#
# [323 rows x 3 columns]

# %%
summer_medals = df[df['Season']=='Summer'].groupby(['region', 'Medal']).size().reset_index()
summer_medals.columns =['region','Medal', 'count']

# %%
##summer_medals = df.groupby(['region', 'Medal']).size().reset_index()
#summer_medals.columns =['region','Medal', 'count']

# %%
summer_medals.pivot('region','Medal', 'count')
# Out:
# Medal               Bronze   Gold  Silver
# region
# Afghanistan            2.0    NaN     NaN
# Algeria                8.0    5.0     4.0
# Argentina             91.0   91.0    92.0
# Armenia                9.0    2.0     5.0
# Australia            515.0  362.0   456.0
# ...                    ...    ...     ...
# Venezuela             10.0    2.0     3.0
# Vietnam                NaN    1.0     3.0
# Virgin Islands, US     NaN    NaN     1.0
# Zambia                 1.0    NaN     1.0
# Zimbabwe               1.0   17.0     4.0
#
# [134 rows x 3 columns]

# %%
summer_medals.pivot('region','Medal', 'count').fillna(0)
# Out:
# Medal               Bronze   Gold  Silver
# region
# Afghanistan            2.0    0.0     0.0
# Algeria                8.0    5.0     4.0
# Argentina             91.0   91.0    92.0
# Armenia                9.0    2.0     5.0
# Australia            515.0  362.0   456.0
# ...                    ...    ...     ...
# Venezuela             10.0    2.0     3.0
# Vietnam                0.0    1.0     3.0
# Virgin Islands, US     0.0    0.0     1.0
# Zambia                 1.0    0.0     1.0
# Zimbabwe               1.0   17.0     4.0
#
# [134 rows x 3 columns]

# %%
summer_medals_20 = summer_medals.pivot('region', 'Medal', 'count').fillna(0).sort_values(['Gold'],ascending=False).head(20)

# %%
summer_medals_20.plot(kind='bar')
plt.xlabel('Country')
plt.title('Medals by Country- Summer olympics')
fig = plt.gcf()
fig.set_size_inches(18.5,10.5)
plt.show()

# %% [markdown]
# ### Number of medals in winter olympics

# %%
winter_medals = df[df['Season']=='Winter'].groupby(['region', 'Medal']).size().reset_index()
winter_medals.columns =['region','Medal', 'count']

# %%
winter_medals.pivot('region','Medal', 'count')
# Out:
# Medal           Bronze   Gold  Silver
# region
# Australia          7.0    6.0     3.0
# Austria          103.0   79.0    98.0
# Belarus            5.0    6.0     4.0
# Belgium            7.0    2.0     4.0
# Bulgaria           3.0    1.0     2.0
# Canada           107.0  305.0   199.0
# China             34.0   16.0    30.0
# Croatia            1.0    4.0     6.0
# Czech Republic   109.0   29.0    93.0
# Denmark            NaN    NaN     5.0
# Estonia            1.0    4.0     2.0
# Finland          215.0   66.0   145.0
# France            79.0   36.0    35.0
# Germany          196.0  226.0   208.0
# Hungary            8.0    NaN     4.0
# India              NaN    7.0     NaN
# Italy             77.0   57.0    57.0
# Japan             24.0   17.0    22.0
# Kazakhstan         3.0    1.0     3.0
# Latvia             7.0    NaN     8.0
# Liechtenstein      5.0    2.0     2.0
# Luxembourg         NaN    NaN     2.0
# Nepal              NaN    1.0     NaN
# Netherlands       42.0   42.0    38.0
# New Zealand        NaN    NaN     1.0
# North Korea        1.0    NaN     1.0
# Norway           127.0  151.0   165.0
# Poland            11.0    6.0    10.0
# Romania            2.0    NaN     NaN
# Russia           184.0  379.0   196.0
# Serbia             1.0    NaN     6.0
# Slovakia           1.0    2.0     2.0
# Slovenia          12.0    2.0     4.0
# South Korea       10.0   50.0    26.0
# Spain              1.0    1.0     NaN
# Sweden           177.0  125.0   126.0
# Switzerland      129.0   76.0    70.0
# UK                31.0   42.0    10.0
# USA              161.0  166.0   308.0
# Ukraine            5.0    5.0     1.0
# Uzbekistan         NaN    1.0     NaN

# %%
winter_medals_20 = winter_medals.pivot('region', 'Medal', 'count').fillna(0).sort_values(['Gold'],ascending=False).head(20)

# %%
winter_medals_20.plot(kind='bar')
plt.xlabel('Country')
plt.title('Medals by Country- Winter olympics')
fig = plt.gcf()
fig.set_size_inches(18.5,10.5)
plt.show()

# %% [markdown]
# ### Number of participants by year

# %%
 year=df['Year'].value_counts()

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=year.index, y=year.values)
plt.xticks(rotation=90)
plt.xlabel("Year")
plt.ylabel("Number of athletes")
plt.title("Number of participants by year")
plt.show()

# %% [markdown]
# ### Number of participants by year and gender

# %%
year_sex_medal=df.groupby(['Year', 'Sex'])['Medal'].count().reset_index()

# %%
year_sex_medal.head()
# Out:
#    Year Sex  Medal
# 0  1896   M    143
# 1  1900   F     13
# 2  1900   M    591
# 3  1904   F     10
# 4  1904   M    476

# %%
year_sex_medal_pivot=year_sex_medal.pivot(index='Year', columns='Sex', values='Medal').fillna(0)

# %%
year_sex_medal_pivot.head()
# Out:
# Sex      F      M
# Year
# 1896   0.0  143.0
# 1900  13.0  591.0
# 1904  10.0  476.0
# 1906   6.0  452.0
# 1908  16.0  815.0

# %%
plt.figure(figsize=(20,10))
fig=plt.gcf()
year_sex_medal_pivot.plot(kind='line')
plt.xlabel('Year')
plt.ylabel('Number of participants')
plt.title('Number of participants by year and gender')
plt.show()

# %% [markdown]
# ### Number of events in each sports in the summer olympics

# %%
sport_summer=df[df['Season']=='Summer']['Sport'].value_counts().sort_values(ascending=False).head(20)

# %%
sport_summer.head()
# Out:
# Athletics     38624
# Gymnastics    26707
# Swimming      23195
# Shooting      11448
# Cycling       10859
# Name: Sport, dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.barplot(y=sport_summer.index, x=sport_summer.values, palette='magma')
plt.xlabel('Number of events')
plt.ylabel('Sport')
plt.xticks(rotation=90)
plt.title("Number of events in each sport in the summer olympics")
plt.show()

# %% [markdown]
# ### Number of events in each sport in the winter olympics

# %%
sport_winter=df[df['Season']=='Winter']['Sport'].value_counts().sort_values(ascending=False)

# %%
sport_winter.head()
# Out:
# Cross Country Skiing    9133
# Alpine Skiing           8829
# Speed Skating           5613
# Ice Hockey              5456
# Biathlon                4893
# Name: Sport, dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.barplot(y=sport_winter.head(20).index, x=sport_winter.head(20).values, palette='magma')
plt.xlabel('Number of events')
plt.ylabel('Sport')
plt.xticks(rotation=90)
plt.title("Number of events in each sport in the winter Olympics")
plt.show()

# %% [markdown]
# ### How many different countries compete in the Summer Olympics each year?

# %%
summer_year_region=df[df['Season']=='Summer'].groupby('Year')['region'].nunique()

# %%
plt.figure(figsize=(12, 8))
sns.pointplot(x=summer_year_region.index, y=summer_year_region.values)
plt.xticks(rotation=90)
plt.xlabel("Year")
plt.ylabel('Different country number')
plt.show()

# %% [markdown]
# ### Male-Female Ratio in olympics

# %%
sex_count=df.groupby(['Year', 'Sex'])['ID'].nunique().reset_index()

# %%
sex_count.head()
# Out:
#    Year Sex    ID
# 0  1896   M   176
# 1  1900   F    23
# 2  1900   M  1201
# 3  1904   F     6
# 4  1904   M   644

# %%
sex_count.columns=['Year','Sex','count']

# %%
sex_count_pivot=sex_count.pivot(index='Year', columns='Sex', values='count').fillna(0)

# %%
plt.figure(figsize=(20,10))
sex_count_pivot.plot(kind='bar')
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
plt.xlabel("Year")
plt.ylabel("number of athletes")
plt.title("Male-Female Ratio in olympics")
plt.show()

# %% [markdown]
# ### Medals by age

# %%
age_medal=events.groupby('Age')['Medal'].count().reset_index()

# %%
age_medal.head()
# Out:
#     Age  Medal
# 0  17.0      1
# 1  18.0      1
# 2  19.0      3
# 3  21.0      2
# 4  22.0      5

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Age',y='Medal', data=age_medal)
plt.title('Medals by age')
plt.xlabel('Age')
plt.ylabel('Number of medals')
plt.show()

# %% [markdown]
# ### Age- Distribution of Gold Medals

# %%
goldMedal=df[df['Medal']=='Gold']
goldMedal.head()
# Out:
#     ID                     Name Sex   Age  Height  Weight            Team  \
# 3    4     Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 42  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 44  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 48  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 60  20       Kjetil Andr Aamodt   M  20.0   176.0    85.0          Norway
#
#     NOC        Games  Year  Season         City          Sport  \
# 3   DEN  1900 Summer  1900  Summer        Paris     Tug-Of-War
# 42  FIN  1948 Summer  1948  Summer       London     Gymnastics
# 44  FIN  1948 Summer  1948  Summer       London     Gymnastics
# 48  FIN  1948 Summer  1948  Summer       London     Gymnastics
# 60  NOR  1992 Winter  1992  Winter  Albertville  Alpine Skiing
#
#                                Event Medal   region notes
# 3        Tug-Of-War Men's Tug-Of-War  Gold  Denmark   NaN
# 42  Gymnastics Men's Team All-Around  Gold  Finland   NaN
# 44      Gymnastics Men's Horse Vault  Gold  Finland   NaN
# 48  Gymnastics Men's Pommelled Horse  Gold  Finland   NaN
# 60       Alpine Skiing Men's Super G  Gold   Norway   NaN

# %%
import warnings
warnings.filterwarnings('ignore')
plt.figure(figsize=(20, 10))
plt.tight_layout()
sns.countplot(goldMedal['Age'])
plt.xticks(rotation=90)
plt.title('Distribution of Gold Medals')
plt.show()

# %%
country=df[df['region']=='India']
country.head()
# Out:
#       ID                             Name Sex   Age  Height  Weight   Team  \
# 505  281                   S. Abdul Hamid   M   NaN     NaN     NaN  India
# 506  281                   S. Abdul Hamid   M   NaN     NaN     NaN  India
# 895  512  Shiny Kurisingal Abraham-Wilson   F  19.0   167.0    53.0  India
# 896  512  Shiny Kurisingal Abraham-Wilson   F  19.0   167.0    53.0  India
# 897  512  Shiny Kurisingal Abraham-Wilson   F  23.0   167.0    53.0  India
#
#      NOC        Games  Year  Season         City      Sport  \
# 505  IND  1928 Summer  1928  Summer    Amsterdam  Athletics
# 506  IND  1928 Summer  1928  Summer    Amsterdam  Athletics
# 895  IND  1984 Summer  1984  Summer  Los Angeles  Athletics
# 896  IND  1984 Summer  1984  Summer  Los Angeles  Athletics
# 897  IND  1988 Summer  1988  Summer        Seoul  Athletics
#
#                                       Event Medal region notes
# 505      Athletics Men's 110 metres Hurdles   NaN  India   NaN
# 506      Athletics Men's 400 metres Hurdles   NaN  India   NaN
# 895            Athletics Women's 800 metres   NaN  India   NaN
# 896  Athletics Women's 4 x 400 metres Relay   NaN  India   NaN
# 897            Athletics Women's 800 metres   NaN  India   NaN

# %%
India=df[df['region']=='India'].groupby(['Name', 'Medal']).size().reset_index()
India.columns=['Name','Medal','count']
India
# Out:
#                                       Name   Medal  count
# 0                           Abhinav Bindra    Gold      1
# 1                          Ahmed Sher Khan    Gold      1
# 2                      Ahsan Muhammad Khan    Gold      1
# 3                      Ajitpal Singh Kular  Bronze      2
# 4                           Akhtar Hussain    Gold      1
# ..                                     ...     ...    ...
# 158           Walter Louis Joseph de Sousa    Gold      1
# 159  William James "Willie" Goodsir-Cullen    Gold      1
# 160         William Patrick "Pat" Sullivan    Gold      1
# 161                         Yogeshwar Dutt  Bronze      1
# 162                            Zafar Iqbal    Gold      1
#
# [163 rows x 3 columns]

# %%
India.pivot('Name','Medal', 'count').fillna(0)
# Out:
# Medal                                  Bronze  Gold  Silver
# Name
# Abhinav Bindra                            0.0   1.0     0.0
# Ahmed Sher Khan                           0.0   1.0     0.0
# Ahsan Muhammad Khan                       0.0   1.0     0.0
# Ajitpal Singh Kular                       2.0   0.0     0.0
# Akhtar Hussain                            0.0   1.0     0.0
# ...                                       ...   ...     ...
# Walter Louis Joseph de Sousa              0.0   1.0     0.0
# William James "Willie" Goodsir-Cullen     0.0   1.0     0.0
# William Patrick "Pat" Sullivan            0.0   1.0     0.0
# Yogeshwar Dutt                            1.0   0.0     0.0
# Zafar Iqbal                               0.0   1.0     0.0
#
# [148 rows x 3 columns]

# %%
India_medals_20 = India.pivot('Name', 'Medal', 'count').fillna(0).sort_values(['Gold'],ascending=False).head(20)

# %%
India_medals_20.plot(kind='bar')
plt.xlabel('Name')
plt.title('Medals won by Indians olympics')
fig = plt.gcf()
fig.set_size_inches(18.5,10.5)
plt.show()
